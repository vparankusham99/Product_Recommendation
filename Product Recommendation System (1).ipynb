# %%
#Importing the required libraries

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the Dataset

Ratings = pd.read_csv(r"C:\Users\Admin\Downloads\Downloads\ratings.csv")
Ratings
# Out:
#           AKM1MP6P0OYPR  0132793040  5.0  1365811200
# 0        A2CX7LUOHB2NDG  0321732944  5.0  1341100800
# 1        A2NWSAGRHCP8N5  0439886341  1.0  1367193600
# 2        A2WNBOD3WNDNKT  0439886341  3.0  1374451200
# 3        A1GI0U4ZRJA8WN  0439886341  1.0  1334707200
# 4        A1QGNMC6O1VW39  0511189877  5.0  1397433600
# ...                 ...         ...  ...         ...
# 7824476  A2YZI3C9MOHC0L  BT008UKTMW  5.0  1396569600
# 7824477  A322MDK0M89RHN  BT008UKTMW  5.0  1313366400
# 7824478  A1MH90R0ADMIK0  BT008UKTMW  4.0  1404172800
# 7824479  A10M2KEFPEQDHN  BT008UKTMW  4.0  1297555200
# 7824480  A2G81TMIOIDEQQ  BT008V9J9U  5.0  1312675200
#
# [7824481 rows x 4 columns]

# %%
#Shape of the Dataset

Ratings.shape
# Out:
# (7824481, 4)

# %%
#Extracting a general summary of the Dataset using info() function

Ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7824481 entries, 0 to 7824480
# Data columns (total 4 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   AKM1MP6P0OYPR  object
#  1   0132793040     object
#  2   5.0            float64
#  3   1365811200     int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 238.8+ MB

# %%
#Generating the Descriptive statistics of the Dataset by using describe() function.
Ratings.describe()
# Out:
#                 5.0    1365811200
# count  7.824481e+06  7.824481e+06
# mean   4.012337e+00  1.338178e+09
# std    1.380910e+00  6.900426e+07
# min    1.000000e+00  9.127296e+08
# 25%    3.000000e+00  1.315354e+09
# 50%    5.000000e+00  1.361059e+09
# 75%    5.000000e+00  1.386115e+09
# max    5.000000e+00  1.406074e+09

# %%
#Finding the datatypes of the columns
Ratings.dtypes
# Out:
# AKM1MP6P0OYPR     object
# 0132793040        object
# 5.0              float64
# 1365811200         int64
# dtype: object

# %%
#Loading the Dataset with Links updated and sorted according to the productID's and also taken only 120000 rows as the original ones is huge.

df = pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\Files\DataSet Updated.csv")
df
# Out:
#                        USERID   PRODUCTID  RATINGS   TIMESTAMP  \
# 0       A001944026UMZ8T3K5QH1  B00000K4LZ        1  1404345600
# 1       A00766851QZZUBOVF4JFT  161685572X        5  1381276800
# 2       A00995931BE16NG4F52QC  B00005N6KG        5  1368662400
# 3       A01255851ZO1U93P8RKGE  9966294791        5  1385510400
# 4       A014623426J5CM7M12MBW  B00004SABB        5  1361836800
# ...                       ...         ...      ...         ...
# 119995          AZZST8OYL5P4Q  B00000JPPI        5  1060732800
# 119996          AZZUBI2MEAHI9  B00002SWHH        5   959644800
# 119997          AZZX23UGJGKTT  B00005QBUU        4  1356480000
# 119998          AZZZEWADNFNUM  B00004RG6K        2   995328000
# 119999          AZZZEWADNFNUM  B00004Y7ZP        5   997401600
#
#                                                     LINKS
# 0       https://www.amazon.in/Adidas-Mens-Regular-T-Sh...
# 1       https://www.amazon.in/Charging-Adapter-Connect...
# 2       https://www.amazon.com/000-Business-Cards-Jewe...
# 3       https://www.amazon.in/India-Converter-200-Watt...
# 4       https://www.amazon.in/WorldCare%C2%AE-1977-199...
# ...                                                   ...
# 119995  https://www.amazon.in/Adidas-Cotton-Messi-Shir...
# 119996  https://www.amazon.in/ACCOX-Sleeves-Regular-Ch...
# 119997  https://www.amazon.com/0-12inch-Classical-Buff...
# 119998  https://www.amazon.in/Acrylic-Repeat-Car-Hangi...
# 119999  https://www.amazon.com/Babo-Botanicals-Essenti...
#
# [120000 rows x 5 columns]

# %%
#Creating a copy of the original Dataset
dfcopy=df.copy()
dfcopy
# Out:
#                        USERID   PRODUCTID  RATINGS   TIMESTAMP  \
# 0       A001944026UMZ8T3K5QH1  B00000K4LZ        1  1404345600
# 1       A00766851QZZUBOVF4JFT  161685572X        5  1381276800
# 2       A00995931BE16NG4F52QC  B00005N6KG        5  1368662400
# 3       A01255851ZO1U93P8RKGE  9966294791        5  1385510400
# 4       A014623426J5CM7M12MBW  B00004SABB        5  1361836800
# ...                       ...         ...      ...         ...
# 119995          AZZST8OYL5P4Q  B00000JPPI        5  1060732800
# 119996          AZZUBI2MEAHI9  B00002SWHH        5   959644800
# 119997          AZZX23UGJGKTT  B00005QBUU        4  1356480000
# 119998          AZZZEWADNFNUM  B00004RG6K        2   995328000
# 119999          AZZZEWADNFNUM  B00004Y7ZP        5   997401600
#
#                                                     LINKS
# 0       https://www.amazon.in/Adidas-Mens-Regular-T-Sh...
# 1       https://www.amazon.in/Charging-Adapter-Connect...
# 2       https://www.amazon.com/000-Business-Cards-Jewe...
# 3       https://www.amazon.in/India-Converter-200-Watt...
# 4       https://www.amazon.in/WorldCare%C2%AE-1977-199...
# ...                                                   ...
# 119995  https://www.amazon.in/Adidas-Cotton-Messi-Shir...
# 119996  https://www.amazon.in/ACCOX-Sleeves-Regular-Ch...
# 119997  https://www.amazon.com/0-12inch-Classical-Buff...
# 119998  https://www.amazon.in/Acrylic-Repeat-Car-Hangi...
# 119999  https://www.amazon.com/Babo-Botanicals-Essenti...
#
# [120000 rows x 5 columns]

# %%
#The first five columns of the dataset
df.head()
# Out:
#                   USERID   PRODUCTID  RATINGS   TIMESTAMP  \
# 0  A001944026UMZ8T3K5QH1  B00000K4LZ        1  1404345600
# 1  A00766851QZZUBOVF4JFT  161685572X        5  1381276800
# 2  A00995931BE16NG4F52QC  B00005N6KG        5  1368662400
# 3  A01255851ZO1U93P8RKGE  9966294791        5  1385510400
# 4  A014623426J5CM7M12MBW  B00004SABB        5  1361836800
#
#                                                LINKS
# 0  https://www.amazon.in/Adidas-Mens-Regular-T-Sh...
# 1  https://www.amazon.in/Charging-Adapter-Connect...
# 2  https://www.amazon.com/000-Business-Cards-Jewe...
# 3  https://www.amazon.in/India-Converter-200-Watt...
# 4  https://www.amazon.in/WorldCare%C2%AE-1977-199...

# %%
#The last five columns of the dataset
df.tail()
# Out:
#                USERID   PRODUCTID  RATINGS   TIMESTAMP  \
# 119995  AZZST8OYL5P4Q  B00000JPPI        5  1060732800
# 119996  AZZUBI2MEAHI9  B00002SWHH        5   959644800
# 119997  AZZX23UGJGKTT  B00005QBUU        4  1356480000
# 119998  AZZZEWADNFNUM  B00004RG6K        2   995328000
# 119999  AZZZEWADNFNUM  B00004Y7ZP        5   997401600
#
#                                                     LINKS
# 119995  https://www.amazon.in/Adidas-Cotton-Messi-Shir...
# 119996  https://www.amazon.in/ACCOX-Sleeves-Regular-Ch...
# 119997  https://www.amazon.com/0-12inch-Classical-Buff...
# 119998  https://www.amazon.in/Acrylic-Repeat-Car-Hangi...
# 119999  https://www.amazon.com/Babo-Botanicals-Essenti...

# %%
#Finding if there are any null values in the dataset 

df.isnull().sum() #there are no null values in the data
# Out:
# USERID       0
# PRODUCTID    0
# RATINGS      0
# TIMESTAMP    0
# LINKS        0
# dtype: int64

# %%
#Finding the datatypes 

df.dtypes
# Out:
# USERID       object
# PRODUCTID    object
# RATINGS       int64
# TIMESTAMP     int64
# LINKS        object
# dtype: object

# %%
#Finding the shape of the dataset

#Taken only 120000 rows for the model because the original one is too huge.
df.shape #It is
# Out:
# (120000, 5)

# %%
#Descriptive statistics of the Dataset
df.describe()
# Out:
#              RATINGS     TIMESTAMP
# count  120000.000000  1.200000e+05
# mean        4.034392  1.198743e+09
# std         1.353400  1.601853e+08
# min         1.000000  9.127296e+08
# 25%         4.000000  1.019758e+09
# 50%         5.000000  1.231718e+09
# 75%         5.000000  1.358554e+09
# max         5.000000  1.405987e+09

# %%
#Dropping the timestamp column as it is not required for the model building 
df2 = df.drop("TIMESTAMP", axis='columns')
df2
# Out:
#                        USERID   PRODUCTID  RATINGS  \
# 0       A001944026UMZ8T3K5QH1  B00000K4LZ        1
# 1       A00766851QZZUBOVF4JFT  161685572X        5
# 2       A00995931BE16NG4F52QC  B00005N6KG        5
# 3       A01255851ZO1U93P8RKGE  9966294791        5
# 4       A014623426J5CM7M12MBW  B00004SABB        5
# ...                       ...         ...      ...
# 119995          AZZST8OYL5P4Q  B00000JPPI        5
# 119996          AZZUBI2MEAHI9  B00002SWHH        5
# 119997          AZZX23UGJGKTT  B00005QBUU        4
# 119998          AZZZEWADNFNUM  B00004RG6K        2
# 119999          AZZZEWADNFNUM  B00004Y7ZP        5
#
#                                                     LINKS
# 0       https://www.amazon.in/Adidas-Mens-Regular-T-Sh...
# 1       https://www.amazon.in/Charging-Adapter-Connect...
# 2       https://www.amazon.com/000-Business-Cards-Jewe...
# 3       https://www.amazon.in/India-Converter-200-Watt...
# 4       https://www.amazon.in/WorldCare%C2%AE-1977-199...
# ...                                                   ...
# 119995  https://www.amazon.in/Adidas-Cotton-Messi-Shir...
# 119996  https://www.amazon.in/ACCOX-Sleeves-Regular-Ch...
# 119997  https://www.amazon.com/0-12inch-Classical-Buff...
# 119998  https://www.amazon.in/Acrylic-Repeat-Car-Hangi...
# 119999  https://www.amazon.com/Babo-Botanicals-Essenti...
#
# [120000 rows x 4 columns]

# %%
#General summary of the dataset.
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120000 entries, 0 to 119999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   USERID     120000 non-null  object
#  1   PRODUCTID  120000 non-null  object
#  2   RATINGS    120000 non-null  int64
#  3   LINKS      120000 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 3.7+ MB

# %%
#Finding the datatypes of the columns
df2.dtypes
# Out:
# USERID       object
# PRODUCTID    object
# RATINGS       int64
# LINKS        object
# dtype: object

# %%
#Finding if there are any null values

df2.isnull().sum() #There are no null values in the Dataset.
# Out:
# USERID       0
# PRODUCTID    0
# RATINGS      0
# LINKS        0
# dtype: int64

# %%
df2
# Out:
#                        USERID   PRODUCTID  RATINGS  \
# 0       A001944026UMZ8T3K5QH1  B00000K4LZ        1
# 1       A00766851QZZUBOVF4JFT  161685572X        5
# 2       A00995931BE16NG4F52QC  B00005N6KG        5
# 3       A01255851ZO1U93P8RKGE  9966294791        5
# 4       A014623426J5CM7M12MBW  B00004SABB        5
# ...                       ...         ...      ...
# 119995          AZZST8OYL5P4Q  B00000JPPI        5
# 119996          AZZUBI2MEAHI9  B00002SWHH        5
# 119997          AZZX23UGJGKTT  B00005QBUU        4
# 119998          AZZZEWADNFNUM  B00004RG6K        2
# 119999          AZZZEWADNFNUM  B00004Y7ZP        5
#
#                                                     LINKS
# 0       https://www.amazon.in/Adidas-Mens-Regular-T-Sh...
# 1       https://www.amazon.in/Charging-Adapter-Connect...
# 2       https://www.amazon.com/000-Business-Cards-Jewe...
# 3       https://www.amazon.in/India-Converter-200-Watt...
# 4       https://www.amazon.in/WorldCare%C2%AE-1977-199...
# ...                                                   ...
# 119995  https://www.amazon.in/Adidas-Cotton-Messi-Shir...
# 119996  https://www.amazon.in/ACCOX-Sleeves-Regular-Ch...
# 119997  https://www.amazon.com/0-12inch-Classical-Buff...
# 119998  https://www.amazon.in/Acrylic-Repeat-Car-Hangi...
# 119999  https://www.amazon.com/Babo-Botanicals-Essenti...
#
# [120000 rows x 4 columns]

# %%
df2['RATINGS'].unique()
# Out:
# array([1, 5, 4, 2, 3], dtype=int64)

# %%
print(df2.isnull().sum())
colours = ['Red', 'Green'] 
sns.heatmap(df2.isnull(),cmap=sns.color_palette(colours))


#Green is non-null and Red is null
#There are no null values in the Dataset(its red below Zero)
# Out:
# USERID       0
# PRODUCTID    0
# RATINGS      0
# LINKS        0
# dtype: int64
# <AxesSubplot:>

# %%
df2[df2.duplicated()] #There are no duplicated records present in the Dataset
# Out:
# Empty DataFrame
# Columns: [USERID, PRODUCTID, RATINGS, LINKS]
# Index: []

# %%
#Histogram of the Ratings column in the Dataset
df2.hist(column='RATINGS', grid=True, edgecolor='black')
# Out:
# array([[<AxesSubplot:title={'center':'RATINGS'}>]], dtype=object)

# %%
#PieChart

plt.figure(figsize=(18,10))
#myexplode = [0.2, 0, 0, 0, 0]
plt.pie(df2['RATINGS'].value_counts()[:15],labels =df2['RATINGS'].value_counts()[:15].index, startangle = 360, shadow = True, autopct='%1.2f%%')
plt.title("Pie Chart for Ratings")
plt.show()


#From the Piechart we can interpret that there are 55.06% of Five star ratings

# %%
#Countplot for the Ratings column

plt.figure(figsize=(16,8))
sns.countplot('RATINGS',data=df2)
plt.xticks(rotation=None)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (20, 12))
sns.set(style = "darkgrid")
ax = sns.countplot(y = 'RATINGS', data = df2, palette=("cool_r"),
              order = df2['RATINGS'].value_counts().index)
for p in ax.patches:
    ax.annotate(int(p.get_width()), ((p.get_x() + p.get_width()), p.get_y()), xytext = (-3, -21),
                fontsize = 20, color = '#004d00', textcoords = 'offset points', horizontalalignment = 'right')
plt.title('RATINGS')
plt.show()

# %%
#! pip install sweetviz

# %%
import sweetviz as sv

s_r=sv.analyze(df2)
s_r.show_html('rating_report.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report rating_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# Number of unique user id  in the data
print('Number of unique users in Raw data = ', df2['USERID'].nunique())

# Number of unique product id  in the data
print('Number of unique product in Raw data = ',df2['PRODUCTID'].nunique())
# Out:
# Number of unique users in Raw data =  106877
# Number of unique product in Raw data =  8103

# %%
#Checking the top 10 users based on number of times ratings are given.

mostly_rated=df2.groupby('USERID').size().sort_values(ascending=False)[:10]
print('Top 10 users based on ratings: \n',mostly_rated)
# Out:
# Top 10 users based on ratings:
#  USERID
# A231WM2Z2JL0U3    134
# A2BGZ52M908MJY     54
# A1RPTVW5VEOSI      37
# AY8Q1X7G96HV5      37
# A1MJMYLRTZ76ZX     36
# A7Y6AVS576M03      33
# A1NVD0TKNS1GT5     30
# A3MEIR72XKQY88     28
# A6FIAB28IS79       28
# AT2J7H5TRZM8Z      27
# dtype: int64

# %%
counts=df2.USERID.value_counts()
df3=df2[df2.USERID.isin(counts[counts>=15].index)]

print('Number of users who have rated 25 or more items =', len(df3))
print('Number of unique users in the final data = ', df3['USERID'].nunique())
print('Number of unique products in the final data = ', df3['USERID'].nunique())
# Out:
# Number of users who have rated 25 or more items = 1010
# Number of unique users in the final data =  39
# Number of unique products in the final data =  39

# %% [markdown]
# # Train-Test Splitting

# %%
#Splitting the Data
from sklearn.model_selection import train_test_split

#Split the data randomnly into train and test datasets into 70:30 ratio
train_data, test_data = train_test_split(df2, test_size = 0.3, random_state=0)
train_data.head()
# Out:
#                USERID   PRODUCTID  RATINGS  \
# 89228  A3TFLI11T4K9AK  1400532655        3
# 82588  A3M1V9TUPUOQZG  B00005AB9R        5
# 67061  A345IE3GGCV7FY  B00004YV6J        5
# 62895  A2ZCKFU3ESS2U3  B00005JDDZ        1
# 57885  A2TOR98Z09NNE7  B00005LEOC        5
#
#                                                    LINKS
# 89228  https://www.amazon.in/13-eZell-Ultra-Thin-Prot...
# 82588  https://www.amazon.com/5014104-Hollister-Two-p...
# 67061  https://www.amazon.com/Cortizone-10-Strength-O...
# 62895  https://www.amazon.com/808-Singsation-Karaoke-...
# 57885  https://www.amazon.com/Avedis-Zildjian-Company...

# %%
print('Shape of training data: ',train_data.shape)
print('Shape of testing data: ',test_data.shape)
# Out:
# Shape of training data:  (84000, 4)
# Shape of testing data:  (36000, 4)

# %%
#Count of user_id for each unique product as recommendation score 

train_data_grouped = train_data.groupby('PRODUCTID').agg({'USERID': 'count'}).reset_index()
train_data_grouped.rename(columns = {'USERID': 'score'},inplace=True)
train_data_grouped.head(40)
# Out:
#      PRODUCTID  score
# 0   059400232X      3
# 1   089933623X      2
# 2   094339676X      1
# 3   1034385789      3
# 4   1039869017      2
# 5   1085901386      1
# 6   1094441252      3
# 7   1182702627      3
# 8   1254875778      3
# 9   134048160X      1
# 10  1348510390      1
# 11  1394860919     13
# 12  1400501466    185
# 13  1400501474     19
# 14  1400501520     51
# 15  1400501741     15
# 16  1400501776     87
# 17  1400501784      2
# 18  1400532620    112
# 19  1400532655    345
# 20  140053271X    309
# 21  1400532736     58
# 22  1400599997    158
# 23  1400666937      2
# 24  1400698987    101
# 25  1400699169     31
# 26  1400699894     13
# 27  1427695024      1
# 28  1444501399      2
# 29  1575839415      1
# 30  1590744306     10
# 31  1593152523      1
# 32  1594243034      1
# 33  1600775160      1
# 34  1600859453      2
# 35  1610130804      1
# 36  1615513388      5
# 37  1615527613     23
# 38  161552763X     19
# 39  1615527648      5

# %%
#Sort the products on recommendation score 
train_data_sort = train_data_grouped.sort_values(['score', 'PRODUCTID'], ascending = [0,1]) 
      
#Generate a recommendation rank based upon score 
train_data_sort['rank'] = train_data_sort['score'].rank(ascending=0, method='first') 
          
#Get the top 5 recommendations 
popularity_recommendations = train_data_sort.head(5) 
popularity_recommendations
# Out:
#        PRODUCTID  score  rank
# 4515  B00004ZCJE   1793   1.0
# 1778  B00001P4ZH   1462   2.0
# 2856  B00004T8R2   1205   3.0
# 1907  B00001WRSJ   1078   4.0
# 6517  B00005N6KG    942   5.0

# %%
# Use popularity based recommender model to make predictions
def recommend(user_id):     
    user_recommendations = popularity_recommendations 
          
    #Add user_id column for which the recommendations are being generated 
    user_recommendations['USERID'] = user_id 
      
    #Bring user_id column to the front 
    cols = user_recommendations.columns.tolist() 
    cols = cols[-1:] + cols[:-1] 
    user_recommendations = user_recommendations[cols] 
          
    return user_recommendations

# %%
import warnings
warnings.filterwarnings('ignore')
find_recom = [10,100,150]   # This list is user choice.
for i in find_recom:
    print("The list of recommendations for the UserID: %d\n" %(i))
    print(recommend(i))    
    print("\n")
# Out:
# The list of recommendations for the UserID: 10
#
#       USERID   PRODUCTID  score  rank
# 4515      10  B00004ZCJE   1793   1.0
# 1778      10  B00001P4ZH   1462   2.0
# 2856      10  B00004T8R2   1205   3.0
# 1907      10  B00001WRSJ   1078   4.0
# 6517      10  B00005N6KG    942   5.0
#
#
# The list of recommendations for the UserID: 100
#
#       USERID   PRODUCTID  score  rank
# 4515     100  B00004ZCJE   1793   1.0
# 1778     100  B00001P4ZH   1462   2.0
# 2856     100  B00004T8R2   1205   3.0
# 1907     100  B00001WRSJ   1078   4.0
# 6517     100  B00005N6KG    942   5.0
#
#
# The list of recommendations for the UserID: 150
#
#       USERID   PRODUCTID  score  rank
# 4515     150  B00004ZCJE   1793   1.0
# 1778     150  B00001P4ZH   1462   2.0
# 2856     150  B00004T8R2   1205   3.0
# 1907     150  B00001WRSJ   1078   4.0
# 6517     150  B00005N6KG    942   5.0

# %% [markdown]
# # COLLABORATIVE FILTERING RECOMMENDER MODEL

# %%
Amazon_products = pd.concat([train_data, test_data]).reset_index()
Amazon_products.head()
# Out:
#    index          USERID   PRODUCTID  RATINGS  \
# 0  89228  A3TFLI11T4K9AK  1400532655        3
# 1  82588  A3M1V9TUPUOQZG  B00005AB9R        5
# 2  67061  A345IE3GGCV7FY  B00004YV6J        5
# 3  62895  A2ZCKFU3ESS2U3  B00005JDDZ        1
# 4  57885  A2TOR98Z09NNE7  B00005LEOC        5
#
#                                                LINKS
# 0  https://www.amazon.in/13-eZell-Ultra-Thin-Prot...
# 1  https://www.amazon.com/5014104-Hollister-Two-p...
# 2  https://www.amazon.com/Cortizone-10-Strength-O...
# 3  https://www.amazon.com/808-Singsation-Karaoke-...
# 4  https://www.amazon.com/Avedis-Zildjian-Company...

# %%
#Taking the first 10000 entries as sample Dataframe
Amazon_ratings = df2.head(10000)

# %%
#Creating a pivot table
ratings_matrix = Amazon_ratings.pivot_table(values='RATINGS', index='USERID', columns=['PRODUCTID','LINKS'], fill_value=0)
ratings_matrix.head()
# Out:
# PRODUCTID                                                                                                                                                                                                                                                                        094339676X  \
# LINKS                 https://www.amazon.in/Neoprene-Sleeve-Cover-Macbook-Retina/dp/B0751F68XT/ref=sr_1_9419?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159314&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-9419
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                                                                                                                                                                                                            1034385789  \
# LINKS                 https://www.amazon.in/Cable-Xiaomi-Original-Charging-USB-Black/dp/B0B7BPW52D/ref=sr_1_8350?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159439&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-8350
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                                                                                                                                                                                                          1039869017  \
# LINKS                 https://www.amazon.in/Protect-AppleCare-Services-iPhone-Year/dp/B0BF4TLLSD/ref=sr_1_8353?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159439&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-8353
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                                                                                                                                                                                                               1394860919  \
# LINKS                 https://www.amazon.in/2-5inch-SATA3-0-Adapter-Converter-Supported/dp/B0B1WZMM7P/ref=sr_1_8332?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159442&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-8332
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                                                                                                                                                                                                               1400501466  \
# LINKS                 https://www.amazon.in/2-5inch-SATA3-0-Adapter-Converter-Supported/dp/B0B1WZMM7P/ref=sr_1_8190?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159459&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-8190
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                                                                                                                                                                                                              1400501474  \
# LINKS                 https://www.amazon.in/13-eZell-Ultra-Thin-Protective-Transparent/dp/B09GYK77C7/ref=sr_1_8022?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159476&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-8022
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                                                                                                                                                                                                                    1400501520  \
# LINKS                 https://www.amazon.in/AirCase-Signature-11-6-Inch-12-5-Inch-Black-Grey/dp/B09DVJ46GM/ref=sr_1_7933?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159488&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-7933
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                                                                                                                                                                                                  1400501741  \
# LINKS                 https://www.amazon.in/Aiwa-RS-X60-Diviner-Ace-Medium/dp/B09H7BNL1B/ref=sr_1_7915?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159491&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-7915
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                                                                                                                                                                                                                  1400501776  \
# LINKS                 https://www.amazon.in/Adapter-Converter-Headphone-Connector-Function/dp/B0B2P8CCB6/ref=sr_1_7900?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159494&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-7900
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                                                                                                                                                                                                                  1400532620  \
# LINKS                 https://www.amazon.in/Adapter-Converter-Headphone-Connector-Function/dp/B0B2P8CCB6/ref=sr_1_7661?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159522&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-7661
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID              ...  \
# LINKS                  ...
# USERID                 ...
# A001944026UMZ8T3K5QH1  ...
# A00766851QZZUBOVF4JFT  ...
# A00995931BE16NG4F52QC  ...
# A01255851ZO1U93P8RKGE  ...
# A014623426J5CM7M12MBW  ...
#
# PRODUCTID                                                                                                  B00005T3EV  \
# LINKS                 https://www.amazon.com/Andrea-And-2979-Orchestra-Cello-Rosin/dp/B00HYMAUM0?_encoding=UTF8&psc=1
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                     B00005T3EW  \
# LINKS                 https://www.amazon.com/A-B-Dark-Rosin-for-Cello/dp/B000BN2ZXG?_encoding=UTF8&psc=1
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                              B00005T3EY  \
# LINKS                 https://www.amazon.com/Accord-Medium-Standard-Cello-Case/dp/B00KLDBPZU?_encoding=UTF8&psc=1
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                          B00005T3EZ  \
# LINKS                 https://www.amazon.com/ANDREA-rosin-SOLO-Violin-FULL/dp/B013RJMHBU?_encoding=UTF8&psc=1
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                                       B00005T3FC  \
# LINKS                 https://www.amazon.com/Column-Spruce-String-Instruments-Accessory/dp/B083DDK4T8?_encoding=UTF8&psc=1
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                                               B00005T3FD  \
# LINKS                 https://www.amazon.com/2Pieces-Adjustable-Eliminator-Suppressor-Eliminate/dp/B08B3GQVXS?_encoding=UTF8&psc=1
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                                                           B00005T3FO  \
# LINKS                 https://www.amazon.com/Adjustable-Lightweight-Design-Universal-Directional-Microphone/dp/B088FHKMYG?_encoding=UTF8&psc=1
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                                B00005T3FP  \
# LINKS                 https://www.amazon.com/Chorus-dedicated-Sheet-Music-Folder/dp/B071NG6QD6?_encoding=UTF8&psc=1
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                                 B00005T3FS  \
# LINKS                 https://www.amazon.com/Grover-Trophy-Sheet-Music-Folder-307/dp/B000XZWZFU?_encoding=UTF8&psc=1
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# PRODUCTID                                                                                               B00005T3FU
# LINKS                 https://www.amazon.com/American-Plating-501G-Trumpet-Lyre/dp/B000EEHHIA?_encoding=UTF8&psc=1
# USERID
# A001944026UMZ8T3K5QH1                                                  0
# A00766851QZZUBOVF4JFT                                                  0
# A00995931BE16NG4F52QC                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A014623426J5CM7M12MBW                                                  0
#
# [5 rows x 2840 columns]

# %%
#Shape of the matric created.
ratings_matrix.shape
# Out:
# (8986, 2840)

# %%
#Transposing the matrix 

X = ratings_matrix.T
X.head()
# Out:
# USERID                                                         A001944026UMZ8T3K5QH1  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...                      0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...                      0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...                      0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                      0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                      0
#
# USERID                                                         A00766851QZZUBOVF4JFT  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...                      0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...                      0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...                      0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                      0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                      0
#
# USERID                                                         A00995931BE16NG4F52QC  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...                      0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...                      0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...                      0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                      0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                      0
#
# USERID                                                         A01255851ZO1U93P8RKGE  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...                      0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...                      0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...                      0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                      0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                      0
#
# USERID                                                         A014623426J5CM7M12MBW  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...                      0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...                      0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...                      0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                      0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                      0
#
# USERID                                                         A01580702BRW77PSJ9X34  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...                      0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...                      0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...                      0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                      0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                      0
#
# USERID                                                         A01852072Z7B68UHLI5UG  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...                      0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...                      0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...                      0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                      0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                      0
#
# USERID                                                         A02459613IS599WTHNWWS  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...                      0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...                      0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...                      0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                      0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                      0
#
# USERID                                                         A0266076X6KPZ6CCHGVS  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...                     0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...                     0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...                     0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                     0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                     0
#
# USERID                                                         A0293130VTX2ZXA70JQS  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...                     0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...                     0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...                     0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                     0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...                     0
#
# USERID                                                         ...  \
# PRODUCTID  LINKS                                               ...
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...  ...
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...  ...
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...  ...
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...  ...
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...  ...
#
# USERID                                                         A1BFDHBXUIRFX9  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...               0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...               0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...               0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
#
# USERID                                                         A1BFEVYLXAD8GZ  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...               0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...               0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...               0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
#
# USERID                                                         A1BFGWPAR3XE0Y  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...               0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...               0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...               0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
#
# USERID                                                         A1BFH3VFSHATNT  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...               0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...               0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...               0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
#
# USERID                                                         A1BFJNUPYC2EEB  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...               0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...               0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...               0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
#
# USERID                                                         A1BFM0WY9XKDIB  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...               0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...               0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...               0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
#
# USERID                                                         A1BFMPKMP7RU49  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...               0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...               0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...               0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
#
# USERID                                                         A1BFNBD9CPHHSW  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...               0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...               0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...               0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
#
# USERID                                                         A1BFNXIOZUN19U  \
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...               0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...               0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...               0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
#
# USERID                                                         A1BFOCCRVN7HHK
# PRODUCTID  LINKS
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...               0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...               0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...               0
# 1394860919 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
# 1400501466 https://www.amazon.in/2-5inch-SATA3-0-Adapter-C...               0
#
# [5 rows x 8986 columns]

# %%
#Shape of the matrix after it is transposed.
X.shape
# Out:
# (2840, 8986)

# %%
#Calling a variable 
X1 = X

# %%
#Importing the required libraries.
import sklearn
from sklearn.decomposition import TruncatedSVD

# %%
#Fitting the matrix into the model

SVD = TruncatedSVD(n_components=10)
decomposed_matrix = SVD.fit_transform(X)
decomposed_matrix.shape
# Out:
# (2840, 10)

# %%
#Correlation matrix of the matrix which was fit into the model
correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (2840, 2840)

# %%
#Checking the 99th row

X.index[99]
# Out:
# ('970407998',
#  'https://www.amazon.in/Amazin-Homes-Stylish-Printed-Computer/dp/B09ZPLLJRP/ref=sr_1_9422?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159314&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-9422')

# %%
#It gives the number in the index when an entry is given.

i = ('970407998',
 'https://www.amazon.in/Amazin-Homes-Stylish-Printed-Computer/dp/B09ZPLLJRP/ref=sr_1_9422?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159314&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-9422')

product_names = list(X.index)
product_ID = product_names.index(i)
product_ID
# Out:
# 99

# %%
#Matrix of both the correlation matrix with the product_ID(variable given above)

correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape
# Out:
# (2840,)

# %%
#Final Recommendations

Recommend = list(X.index[correlation_product_ID > 0.90])

# Removes the item already bought by the customer
Recommend.remove(i) 

Recommend[0:9]
# Out:
# [('594451647',
#   'https://www.amazon.in/AirCase-Earphone-Travel-Organizer-Drives/dp/B07XZ7YX9M/ref=sr_1_9533?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159303&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-9533'),
#  ('7538637400',
#   'https://www.amazon.in/AAC90-Protective-Shockproof-Compatible-Generation/dp/B0B9BYDHYB/ref=sr_1_5350?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159797&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-5350'),
#  ('9862376740',
#   'https://www.amazon.in/Belkin-Certified-Vision-Playstation-Meters/dp/B097PGJNWT/ref=sr_1_4331?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159920&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-4331'),
#  ('9966569863',
#   'https://www.amazon.in/Amardeep-7Ah-SMF-VRLA-Battery/dp/B00MPJ6BNY/ref=sr_1_3847?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159977&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-3847'),
#  ('9983750341',
#   'https://www.amazon.in/Complete-Protect-1year-Authorised-Smartphones/dp/B0B5GSQM4W/ref=sr_1_3495?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665160020&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-3495'),
#  ('9985024796',
#   'https://www.amazon.in/Complete-Protect-1year-Smartphones-12000-12999/dp/B0B5GP9X75/ref=sr_1_2956?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665160085&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-2956'),
#  ('B00000J48C',
#   'https://www.amazon.in/Leriya-Fashion-Printed-Dresses-X-Large_Black/dp/B09Z86MYP1/ref=sr_1_81?crid=1F48Q7IZJY9JY&keywords=women+dresses&qid=1665172274&qu=eyJxc2MiOiIxMS41MyIsInFzYSI6IjExLjE0IiwicXNwIjoiOC44NCJ9&sprefix=women+dresses%2Caps%2C253&sr=8-81'),
#  ('B00000J4BL',
#   'https://www.amazon.in/Indya-Womens-Regular-Dresses-ETN00292_Maroon_Large/dp/B0B4XCMWGV/ref=sr_1_296?crid=9NYNJAVNN7T5&keywords=women+dresses+cotton&qid=1665172679&qu=eyJxc2MiOiI3LjE1IiwicXNhIjoiNS45NiIsInFzcCI6IjEuMDAifQ%3D%3D&sprefix=women+dresses%2Caps%2C233&sr=8-296'),
#  ('B00000J4GS',
#   'https://www.amazon.in/Amico-Mens-Multicolored-Sneaker-UK/dp/B08D6G54RZ/ref=sr_1_269?crid=IQZYAWAOMM9V&keywords=men+shoes&qid=1665175255&qu=eyJxc2MiOiIxMi4zOSIsInFzYSI6IjEyLjE2IiwicXNwIjoiOS4zMSJ9&sprefix=men+%2Caps%2C436&sr=8-269')]

# %%
#Recommended products as a Dataframe for easy view.

Final_DF = pd.DataFrame(Recommend, columns=['Recommended_product_ID','Recommended_Product_Links'])
Final_DF
# Out:
#    Recommended_product_ID                          Recommended_Product_Links
# 0               594451647  https://www.amazon.in/AirCase-Earphone-Travel-...
# 1              7538637400  https://www.amazon.in/AAC90-Protective-Shockpr...
# 2              9862376740  https://www.amazon.in/Belkin-Certified-Vision-...
# 3              9966569863  https://www.amazon.in/Amardeep-7Ah-SMF-VRLA-Ba...
# 4              9983750341  https://www.amazon.in/Complete-Protect-1year-A...
# ..                    ...                                                ...
# 76             B00005O7CS  https://www.amazon.com/20-Pack-Economy-Electri...
# 77             B00005OP2Z  https://www.amazon.com/Clayton-Picks-AMHSH-Gui...
# 78             B00005RI9L  https://www.amazon.com/24K-Gold-Schilke-French...
# 79             B00005T3A9  https://www.amazon.com/1-pkg-Strong-Black-Carb...
# 80             B00005T3FO  https://www.amazon.com/Adjustable-Lightweight-...
#
# [81 rows x 2 columns]

# %%
test_data
# Out:
#                 USERID   PRODUCTID  RATINGS  \
# 40739   A29XPG4MIXMFG7  B00004SB92        5
# 105532   AJM1MHU6NN6Y9  B00004Y3TO        5
# 45004   A2EQ0QDOSGH6AC  B00002EQCW        5
# 71894   A39Q5JH09VUMR5  B00005ABC5        5
# 11970   A1DOQOHHG83ZXP  B00001P4ZR        4
# ...                ...         ...      ...
# 116764   AWC8CTW8N2XVE  B00003CWG4        5
# 90802   A3V4PJ5OHVFB2C  B000056B2J        5
# 116819   AWF9F3X35WN2I  B00000J0D2        4
# 106121   AK94AGPA2L5GY  B00001OPK4        5
# 42451   A2BSBYI26UYWTQ  B00001ZWXA        5
#
#                                                     LINKS
# 40739   https://www.amazon.in/WorldCare%C2%AE-1977-199...
# 105532  https://www.amazon.com/Control-Bedbugs-Furnitu...
# 45004   https://www.amazon.in/284-ENTERPRISE-Cotton-St...
# 71894   https://www.amazon.com/5011403-Hollister-CeraP...
# 11970   https://www.amazon.in/ACCOX-Printed-Sleeves-Re...
# ...                                                   ...
# 116764  https://www.amazon.in/Levis-Mens-Jeans-18298-1...
# 90802   https://www.amazon.com/5-HOUR-ENERGY-ORANGE-12...
# 116819  https://www.amazon.in/Acko-Extended-Warranty-A...
# 106121  https://www.amazon.in/Cherokee-Unlimited-Solid...
# 42451   https://www.amazon.in/AEROPOSTALE-Black-Button...
#
# [36000 rows x 4 columns]

# %%
#Pickling

# %%
import pickle
from pickle import dump

# %%
dump(SVD,open("SVD.pkl","wb"))

# %%
dump(train_data,open("train.pkl","wb"))

# %%
dump(test_data,open("test.pkl","wb"))

# %% [markdown]
# #The Above Models recommends products based on the user similarity
